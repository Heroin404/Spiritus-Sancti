# %%
import pandas as pd

# %%
D = pd.read_csv("https://github.com/junaart/ForStudents/raw/refs/heads/main/R/Zachet/DataSets/10.csv",sep=";")
display(D)
# Out:
#           okato Субсидии на ГЗ из местных бюджетов  \
# 0    1000000000                             4853,7
# 1    3000000000                               4986
# 2    4000000000                                  0
# 3    5000000000                                 20
# 4    7000000000                            16107,2
# ..          ...                                ...
# 77  94000000000                            17637,2
# 78  95000000000                              26919
# 79  96000000000                                  0
# 80  97000000000                                  0
# 81  98000000000                             218723
#
#    Субсидии на ГЗ из федерального бюджета  \
# 0                                151428,9
# 1                                  473810
# 2                                789836,7
# 3                               2609402,1
# 4                                164127,2
# ..                                    ...
# 77                               154377,8
# ...

# %%
import redis as rd

# %%
r = rd.Redis()
key = "my_key."
for i in range(len(D["okato"])):
    r.set(key+str(i),str(D["okato"].iloc[i]))

# %%
D.columns
# Out:
# Index(['okato', 'Субсидии на ГЗ из местных бюджетов',
#        'Субсидии на ГЗ из федерального бюджета',
#        'Субсидии на НИОКР из местного бюджета',
#        'Субсидии на НИОКР из федерального бюджета',
#        'Гранты из местного бюджета', 'Гранты из федерального бюджета',
#        'Гранты из прочих источников',
#        'Конкурсное финансирование из местного бюджета',
#        'Конкурсное финансирование из федерального бюджета',
#        'Конкурсное финансирование из прочих источников'],
#       dtype='object')

# %%
r = rd.Redis()
key = "my_key2."
for i in range(len(D["Субсидии на ГЗ из местных бюджетов"])):
    r.set(key+str(i),str(D["Субсидии на ГЗ из местных бюджетов"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key3."
for i in range(len(D["Субсидии на ГЗ из федерального бюджета"])):
    r.set(key+str(i),str(D["Субсидии на ГЗ из федерального бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key4."
for i in range(len(D["Субсидии на НИОКР из местного бюджета"])):
    r.set(key+str(i),str(D["Субсидии на НИОКР из местного бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key5."
for i in range(len(D["Субсидии на НИОКР из федерального бюджета"])):
    r.set(key+str(i),str(D["Субсидии на НИОКР из федерального бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key6."
for i in range(len(D["Гранты из местного бюджета"])):
    r.set(key+str(i),str(D["Гранты из местного бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key7."
for i in range(len(D["Гранты из федерального бюджета"])):
    r.set(key+str(i),str(D["Гранты из федерального бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key8."
for i in range(len(D["Гранты из прочих источников"])):
    r.set(key+str(i),str(D["Гранты из прочих источников"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key9."
for i in range(len(D["Конкурсное финансирование из местного бюджета"])):
    r.set(key+str(i),str(D["Конкурсное финансирование из местного бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key10."
for i in range(len(D["Конкурсное финансирование из федерального бюджета"])):
    r.set(key+str(i),str(D["Конкурсное финансирование из федерального бюджета"].iloc[i]))

# %%
r = rd.Redis()
key = "my_key11."
for i in range(len(D["Конкурсное финансирование из прочих источников"])):
    r.set(key+str(i),str(D["Конкурсное финансирование из прочих источников"].iloc[i]))
